# %% [markdown]
# <a href="https://colab.research.google.com/github/swarnava-96/Movie-Recommendation-System/blob/main/Weighted_Hybrid_Technique_for_Recommendation_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Building a Basic Recommendation System using Weighted Hybrid Technique**
#
# ### Importing the necessary libraries and Loading the Dataset

# %%
# Importing the necessary libraries

import numpy as np
import pandas as pd

# %%
cd "/content/drive/MyDrive/Datasets"
# Out:
# /content/drive/MyDrive/Datasets

# %%
# Loading the datasets

credits = pd.read_csv("tmdb_5000_credits.csv")
movies_df = pd.read_csv("tmdb_5000_movies.csv")

# %%
# Lets check the first five rows of the credits dataframe

credits.head()
# Out:
#    movie_id  ...                                               crew
# 0     19995  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1       285  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2    206647  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     49026  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     49529  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 4 columns]

# %%
# Lets check the first five rows of the movies_df dataframe

movies_df.head()
# Out:
#       budget  ... vote_count
# 0  237000000  ...      11800
# 1  300000000  ...       4500
# 2  245000000  ...       4466
# 3  250000000  ...       9106
# 4  260000000  ...       2124
#
# [5 rows x 20 columns]

# %%
# Lets check the shapes of our dataframes

print("credits:", credits.shape)
print("movies_df:", movies_df.shape)
# Out:
# credits: (4803, 4)
# movies_df: (4803, 20)

# %% [markdown]
# ### Lets merge the two dataframes

# %%
# Lets rename the column feature "movie_id" to "id" so that we can join 

credits_columns_renamed = credits.rename(index = str, columns = {"movie_id" : "id"})
movies_df_merge = movies_df.merge(credits_columns_renamed, on = "id")
movies_df_merge.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Lets clean the our dataframe

# %%
# Removing the features that are not required

movies_cleaned_df = movies_df_merge.drop(columns = ["homepage", "title_x", "title_y", "status", "production_countries"])
movies_cleaned_df.head()
# Out:
#       budget  ...                                               crew
# 0  237000000  ...  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  300000000  ...  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  245000000  ...  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  250000000  ...  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  260000000  ...  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
#
# [5 rows x 18 columns]

# %%
movies_cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4803 entries, 0 to 4802
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   id                    4803 non-null   int64
#  3   keywords              4803 non-null   object
#  4   original_language     4803 non-null   object
#  5   original_title        4803 non-null   object
#  6   overview              4800 non-null   object
#  7   popularity            4803 non-null   float64
#  8   production_companies  4803 non-null   object
#  9   release_date          4802 non-null   object
#  10  revenue               4803 non-null   int64
#  11  runtime               4801 non-null   float64
#  12  spoken_languages      4803 non-null   object
#  13  tagline               3959 non-null   object
#  14  vote_average          4803 non-null   float64
#  15  vote_count            4803 non-null   int64
#  16  cast                  4803 non-null   object
#  17  crew                  4803 non-null   object
# dtypes: float64(3), int64(4), object(11)
# memory usage: 712.9+ KB

# %% [markdown]
# ### Using Weighted average for each movie's Average Rating

# %%
# Lets calculate the components used in the formula for calculating weighted average


v = movies_cleaned_df["vote_count"]   # v = number of votes for the movie
R = movies_cleaned_df["vote_average"] # R = average for the movie as a number from 0 to 10
C = movies_cleaned_df["vote_average"].mean()  # C = the mean vote across the whole report 
m = movies_cleaned_df["vote_count"].quantile(0.70)  # m = minimum votes required to be listed in the top 250

# %%
# Calculating the weighted movies average ratings

movies_cleaned_df["weighted_average"] = ((R * v) + (C * m))/(v + m)

# %%
# Lets check the first five rows

movies_cleaned_df.head()
# Out:
#       budget  ... weighted_average
# 0  237000000  ...         7.148013
# 1  300000000  ...         6.807627
# 2  245000000  ...         6.276075
# 3  250000000  ...         7.509565
# 4  260000000  ...         6.098319
#
# [5 rows x 19 columns]

# %%
# Lets rank our movies in terms of "weighted_average" and lets see the features like 'original_title', 'vote_count', 'vote_average','popularity'

movie_sorted_ranking = movies_cleaned_df.sort_values("weighted_average", ascending = False)
movie_sorted_ranking[['original_title', 'vote_count', 'vote_average', 'weighted_average', 'popularity']].head(20)
# Out:
#                                          original_title  ...  popularity
# 1881                           The Shawshank Redemption  ...  136.747729
# 3337                                      The Godfather  ...  143.659698
# 662                                          Fight Club  ...  146.757391
# 3232                                       Pulp Fiction  ...  121.463076
# 65                                      The Dark Knight  ...  187.322927
# 809                                        Forrest Gump  ...  138.133331
# 1818                                   Schindler's List  ...  104.469351
# 3865                                           Whiplash  ...  192.528841
# 96                                            Inception  ...  167.583710
# 1990                            The Empire Strikes Back  ...   78.517830
# 2294                                           千と千尋の神隠し  ...  118.968562
# 95                                         Interstellar  ...  724.247784
# 2731                             The Godfather: Part II  ...  105.792936
# 329       The Lord of the Rings: The Return of the King  ...  123.630332
# 2912                                          Star Wars  ...  126.393695
# 690                                      The Green Mile  ...  103.698022
# 1553                                              Se7en  ...   79.579532
# 262   The Lord of the Rings: The Fellowship of the Ring  ...  138.049577
# 1847                                         GoodFellas  ...   63.654244
# 2091                           The Silence of the Lambs  ...   18.174804
#
# [20 rows x 5 columns]

# %%
# Lets plot the top 10 movies by average votes

# Importing the plotting libraries
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

weight_average = movie_sorted_ranking.sort_values("weighted_average", ascending = False)
plt.figure(figsize = (12, 6))
axis1 = sns.barplot(x = weight_average["weighted_average"].head(10), y = weight_average["original_title"].head(10), data = weight_average)
plt.xlim(4, 10)
plt.title('Best Movies by Average Votes', weight='bold')
plt.xlabel('Weighted Average Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_movies.png')

# %% [markdown]
# In the above barplot we can see that "The Shawshank Redemption" is at the top when compared to others by average votes.

# %% [markdown]
# ### Lets create the same Recommendation System based on Popularity of movies

# %%
popularity = movie_sorted_ranking.sort_values("popularity", ascending = False)

# %%
popularity.head()
# Out:
#         budget  ... weighted_average
# 546   74000000  ...         6.365286
# 95   165000000  ...         7.998100
# 788   58000000  ...         7.334360
# 94   170000000  ...         7.798252
# 127  150000000  ...         7.135687
#
# [5 rows x 19 columns]

# %%
# Lets plot the top 10 movies by popularity

plt.figure(figsize = (12, 6))
ax = sns.barplot(x = popularity["popularity"].head(10), y = popularity["original_title"].head(10), data = popularity)


plt.title("Most Popular Movies by Votes", weight = "bold")
plt.xlabel('Score of Popularity', weight='bold')
plt.ylabel('Movie Title', weight='bold')
plt.savefig('best_popular_movies.png')

# %% [markdown]
# In the above barplot we can see that "Minions" is at the top when compared to others by popularity.

# %% [markdown]
# ### Recommendation based on scaled weighted average and popularity score(Priority is given 50% to both)

# %%
# Feature Scaling

from sklearn.preprocessing import MinMaxScaler
scaling = MinMaxScaler()
movie_scaled_df = scaling.fit_transform(movies_cleaned_df[["weighted_average", "popularity"]])

# Making a dataframe with these two features scaled
movie_normalized_df = pd.DataFrame(movie_scaled_df, columns = ["weighted_average", "popularity"])
movie_normalized_df.head()
# Out:
#    weighted_average  popularity
# 0          0.674339    0.171815
# 1          0.581403    0.158846
# 2          0.436273    0.122635
# 3          0.773054    0.128272
# 4          0.387739    0.050169

# %%
# Appending the movie_normalized dataframe with the movie_cleaned_df

movies_cleaned_df[["normalized_weight_average", "normalized_popularity"]] = movie_normalized_df
movies_cleaned_df.head()
# Out:
#       budget  ... normalized_popularity
# 0  237000000  ...              0.171815
# 1  300000000  ...              0.158846
# 2  245000000  ...              0.122635
# 3  250000000  ...              0.128272
# 4  260000000  ...              0.050169
#
# [5 rows x 21 columns]

# %%
# Creating the Recommendation System

movies_cleaned_df["score"] = movies_cleaned_df["normalized_weight_average"] * 0.5 + movies_cleaned_df["normalized_popularity"] * 0.5
movies_scored_df = movies_cleaned_df.sort_values(["score"], ascending = False)
movies_scored_df[['original_title', 'normalized_weight_average', 'normalized_popularity', 'score']].head(20)
# Out:
#                                          original_title  ...     score
# 95                                         Interstellar  ...  0.866801
# 546                                             Minions  ...  0.730315
# 94                              Guardians of the Galaxy  ...  0.700668
# 788                                            Deadpool  ...  0.656453
# 127                                  Mad Max: Fury Road  ...  0.583481
# 1881                           The Shawshank Redemption  ...  0.578090
# 65                                      The Dark Knight  ...  0.574466
# 3865                                           Whiplash  ...  0.568159
# 3337                                      The Godfather  ...  0.561848
# 662                                          Fight Club  ...  0.560717
# 96                                            Inception  ...  0.551718
# 3232                                       Pulp Fiction  ...  0.544357
# 809                                        Forrest Gump  ...  0.540013
# 199   Pirates of the Caribbean: The Curse of the Bla...  ...  0.525772
# 2294                                           千と千尋の神隠し  ...  0.522761
# 88                                           Big Hero 6  ...  0.522349
# 329       The Lord of the Rings: The Return of the King  ...  0.519308
# 1818                                   Schindler's List  ...  0.518426
# 2912                                          Star Wars  ...  0.517204
# 262   The Lord of the Rings: The Fellowship of the Ring  ...  0.516016
#
# [20 rows x 4 columns]

# %%
# Plottting the top 10 movies based on score

scored_df = movies_cleaned_df.sort_values('score', ascending=False)

plt.figure(figsize=(16,6))

ax = sns.barplot(x=scored_df['score'].head(10), y=scored_df['original_title'].head(10), data=scored_df, palette='deep')

#plt.xlim(3.55, 5.25)
plt.title('Best Rated & Most Popular Blend', weight='bold')
plt.xlabel('Score', weight='bold')
plt.ylabel('Movie Title', weight='bold')

plt.savefig('scored_movies.png')

# %% [markdown]
# Here we see that the best rated and the most popular movie is "Interstellar".
